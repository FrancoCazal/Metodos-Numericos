# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# A = np.array([[14,65,15,12],
#               [11,17,60,12],
#               [60,8,19,11],
#               [15,10,6,65]], dtype=float)

# %%
import numpy as np

A = np.array([[60,8,19,11],
              [14,65,15,12],
              [11,17,60,12],
              [15,10,6,65]], dtype=float)

B = np.array([[3400],
              [5200],
              [5600],
              [5900]], dtype=float)

P = np.array([
    [0],
    [0],
    [0],
    [0]], dtype=float)

n=len(B)
tol=1e-2
m=100
X=P.copy()

# Rutina 3 - Gauss-Seidel
for i in range(m):
    for j in range(n):          
        X[j] = (B[j] - A[j, np.delete(np.arange(n), j) ].dot(X[np.delete(np.arange(n), j) ])) / A[j, j]
    err = np.linalg.norm(X - P)
    normX = np.linalg.norm(X)
    relerr = err / normX
    if tol > err or tol > relerr:
        break
    else:
        P = X.copy()

rta = np.around(X, decimals=6)
print(f"La empresa debe adquirir de los proveedores A, B, C y D respectivamente: \n{rta} kg.")
print(f"La cantidad de iteraciones realizadas fue de: {i+1}")
# Out:
# La empresa debe adquirir de los proveedores A, B, C y D respectivamente:
# [[17.058219]
#  [48.37914 ]
#  [61.724928]
#  [73.692088]] kg.
# La cantidad de iteraciones realizadas fue de: 4
